# %%
import boto3
import pandas as pd
import pyarrow.parquet as pq
import io

# %%
def read_profiles(bucket: str, source: str) -> pd.DataFrame:
    """
    Reads all non-empty Parquet profiling files for a given source from S3.

    Args:
        bucket (str): S3 bucket name
        source (str): Source name (e.g., "payments")

    Returns:
        pd.DataFrame: Concatenated DataFrame of all profiling files
    """
    prefix = f"profiling/source={source}/"
    s3 = boto3.client("s3")

    # List objects in folder
    objects = s3.list_objects_v2(Bucket=bucket, Prefix=prefix).get("Contents", [])
    
    # Filter out empty files
    objects = [obj for obj in objects if obj["Size"] > 0]

    if not objects:
        print(f"No non-empty profiling files found for source: {source}")
        return pd.DataFrame()

    dfs = []
    for obj in objects:
        obj_data = s3.get_object(Bucket=bucket, Key=obj["Key"])
        table = pq.read_table(io.BytesIO(obj_data["Body"].read()))
        dfs.append(table.to_pandas())

    df = pd.concat(dfs, ignore_index=True)
   
    return df

# %%
sources = ["payments",  "merchant", "device", "customer_behavior", "fraud_timing"]
bucket = "danske-bank-project-metadata"

source_columns = {}


all_profiles = []

for source in sources:
    df = read_profiles(bucket, source)
    if not df.empty:
        source_columns[source] = df["column_name"].unique()  
        all_profiles.append(df)
df_profiles = pd.concat(all_profiles, ignore_index=True)
# Quick overview
for source, cols in source_columns.items():
    print(f"\nSource: {source}")
    print(cols)
# Out:
# Source: payments
# <ArrowStringArray>
# [              'tx_id',          'event_time',      'sender_account',
#     'receiver_account',              'amount',     'payment_channel',
#             'location',       'source_system', 'ingestion_timestamp']
# Length: 9, dtype: str
#
# Source: merchant
# <ArrowStringArray>
# [                 'ID',            'Category',                'Type',
#               'Amount',            'Location',       'source_system',
#  'ingestion_timestamp']
# Length: 7, dtype: str
#
# Source: device
# <ArrowStringArray>
# ['device', 'network', 'transaction_id', 'source_system',
#  'ingestion_timestamp']
# Length: 5, dtype: str
#
# Source: customer_behavior
# <ArrowStringArray>
# [              'sender_account',          'avg_amount_last_24h',
#             'tx_count_last_24h',           'max_velocity_score',
#           'mean_velocity_score',           'min_velocity_score',
#         'avg_geo_anomaly_score', 'avg_spending_deviation_score',
#                 'source_system',          'ingestion_timestamp']
# Length: 10, dtype: str
#
# Source: fraud_timing
# <ArrowStringArray>
# [     'transaction_id',           'timestamp',            'location',
#             'is_fraud',          'fraud_type',         'time_of_day',
#          'day_of_week',       'source_system', 'ingestion_timestamp']
# Length: 9, dtype: str

# %%
df
# Out:
#           source          column_name          metric  metric_value  \
# 0   fraud_timing       transaction_id       row_count  5.000000e+06
# 1   fraud_timing       transaction_id      null_count  0.000000e+00
# 2   fraud_timing       transaction_id        null_pct  0.000000e+00
# 3   fraud_timing       transaction_id  distinct_count  5.000000e+06
# 4   fraud_timing            timestamp       row_count  5.000000e+06
# 5   fraud_timing            timestamp      null_count  3.000000e+00
# 6   fraud_timing            timestamp        null_pct  6.000000e-05
# 7   fraud_timing            timestamp  distinct_count  4.999594e+06
# 8   fraud_timing             location       row_count  5.000000e+06
# 9   fraud_timing             location      null_count  5.047000e+04
# 10  fraud_timing             location        null_pct  1.009400e+00
# 11  fraud_timing             location  distinct_count  9.000000e+00
# 12  fraud_timing             is_fraud       row_count  5.000000e+06
# 13  fraud_timing             is_fraud      null_count  0.000000e+00
# 14  fraud_timing             is_fraud        null_pct  0.000000e+00
# 15  fraud_timing             is_fraud  distinct_count  2.000000e+00
# 16  fraud_timing           fraud_type       row_count  5.000000e+06
# 17  fraud_timing           fraud_type      null_count  4.820447e+06
# 18  fraud_timing           fraud_type        null_pct  9.640894e+01
# 19  fraud_timing           fraud_type  distinct_count  2.000000e+00
# 20  fraud_timing          time_of_day       row_count  5.000000e+06
# 21  fraud_timing          time_of_day      null_count  0.000000e+00
